# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoalsilva/kaggle_pandas_exercises/blob/main/kaggle_pandas_course_lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Criar um DataFrame com bananas e apples. Bananas tem 30 e Apples tem 21.
# ### Bonus: crie mais linhas.
# ### Bonus: adicionar nomes aos índices

# %%
fruits = pd.DataFrame({'Apples': [30, 25], 'Bananas': [21, 34]}, ['27/01', '28/01'])

# %%
fruits
# Out:
#        Apples  Bananas
# 27/01      30       21
# 28/01      25       34

# %% [markdown]
# ## 2. Crie um DataFrame com Bananas e Apples com os índices: '2017 Sales'e '2018 Sales'

# %%
fruits_sales = pd.DataFrame({'Apples': [35, 41], 'Bananas': [21, 34]}, index=['2017 Sales', '2018 Sales'])
fruits_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# ## 3. Criar uma variável 'ingredients' com a Series que se pareça com:
#
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index=['Flour', 'Milk', 'Eggs', 'Spam'], name='Dinner')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# ## 4. Ler a fonte de dados csv de revisão de vinhos em um DataFrame chamado reviews

# %%
reviews = pd.read_csv('https://raw.githubusercontent.com/stoltzmaniac/wine-reviews-kaggle/master/winemag-data_first150k.csv')
reviews
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %% [markdown]
# ## 5. Rodar uma celula para criar e mostrar um DataFrame chamado animals

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19
